# %%
import numpy as np
import pandas as pd 
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import requests as rq
from datetime import datetime
from pandas import Series,DataFrame
from io import StringIO
from __future__ import division
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression

sns.set_style('whitegrid')
# %matplotlib inline

# %% [markdown]
# # Network - Input CSV file

# %%
Donald = pd.read_csv('./2016/Donald.csv', encoding='ISO-8859-1', parse_dates = ['timestamp'])
Trump = pd.read_csv('./2016/Trump.csv', encoding='ISO-8859-1', parse_dates = ['timestamp'])
Clinton = pd.read_csv('./2016/Clinton.csv', encoding='ISO-8859-1', parse_dates = ['timestamp'])
Hillary = pd.read_csv('./2016/Hillary.csv', encoding='ISO-8859-1', parse_dates = ['timestamp'])
# Out:
# c:\users\yeshuchuan\appdata\local\programs\python\python36-32\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (198) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# c:\users\yeshuchuan\appdata\local\programs\python\python36-32\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (180) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Donald_Trump= [Donald, Trump]
Donald_Trump_total = pd.concat(Donald_Trump)
Donald_Trump_total.head()
# Out:
#             timestamp       id                      link  \
# 0 2016-07-25 20:36:00  1617878  http://imgur.com/a/8QHBb
# 1 2016-01-03 17:07:00   882383  http://imgur.com/PNH3li7
# 2 2016-09-27 20:50:00  2574116  http://imgur.com/a/3zSGZ
# 3 2016-01-31 17:17:00   800269  http://imgur.com/uieds24
# 4 2016-05-05 23:08:00   355062  http://imgur.com/BgtxDoF
#
#                                              caption              author  \
# 0  cp 666\n Donald Trump\n HP 666/666\n 18.8 m\n ...      politicalhumor
# 1  TAKE ME TO YOUR LEADER\n JESUS NOT DONALD TRUM...  dankchristianmemes
# 2  ONLY THE\n POOR\n AND ONLY THE\n STUPID\n PAY\...      politicalhumor
# 3  WHEN GOD SAID LET THERE BE\n LIGHT\n HE HAD TO...  dankchristianmemes
# 4  4:33 PM\n 91%\n Search in\n #Never Trump\n Dan...                 NaN
#
#   network  likes  Unnamed: 7  Unnamed: 8  Unnamed: 9      ...       \
# 0   imgur    -19         NaN         NaN         NaN      ...
# 1   imgur    -15         NaN         NaN         NaN      ...
# 2   imgur    -13         NaN         NaN         NaN      ...
# 3   imgur    -13         NaN         NaN         NaN      ...
# 4   imgur    -12         NaN         NaN         NaN      ...
#
#    Unnamed: 190  Unnamed: 191  Unnamed: 192  Unnamed: 193  Unnamed: 194  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#    Unnamed: 195  Unnamed: 196  Unnamed: 197  Unnamed: 198  Unnamed: 199
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
# [5 rows x 200 columns]

# %%
Clinton_Hillary= [Clinton, Hillary]
Clinton_Hillary_total = pd.concat(Clinton_Hillary)
Clinton_Hillary_total.head()
# Out:
#    Unnamed: 10  Unnamed: 100  Unnamed: 101  Unnamed: 102  Unnamed: 103  \
# 0          NaN           NaN           NaN           NaN           NaN
# 1          NaN           NaN           NaN           NaN           NaN
# 2          NaN           NaN           NaN           NaN           NaN
# 3          NaN           NaN           NaN           NaN           NaN
# 4          NaN           NaN           NaN           NaN           NaN
#
#    Unnamed: 104  Unnamed: 105  Unnamed: 106  Unnamed: 107  Unnamed: 108  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#           ...          Unnamed: 97  Unnamed: 98  Unnamed: 99  \
# 0         ...                  NaN          NaN          NaN
# 1         ...                  NaN          NaN          NaN
# 2         ...                  NaN          NaN          NaN
# 3         ...                  NaN          NaN          NaN
# 4         ...                  NaN          NaN          NaN
#
#                 author                                            caption  \
# 0  forwardsfromgrandma  Son killed by\n country, in a\n in a\n war sta...
# 1       TumblrInAction  1h\n Why end racism when we can just\n end the...
# 2  forwardsfromgrandma  HILLARY CLINTON SAYS YOU CAN\n KILL A BABY THE...
# 3                4chan  I Liked\n p Message Save\n More\n A Write a co...
# 4       politicalhumor  This is such a hypocritical thing to be on hil...
#
#         id  likes                      link  network           timestamp
# 0  1742494    -20  http://imgur.com/a/lNHED    imgur 2016-08-01 20:56:00
# 1  1633557    -16  http://imgur.com/a/FRGrq    imgur 2016-07-27 00:54:00
# 2  3017540    -14  http://imgur.com/a/giimL    imgur 2016-10-20 07:34:00
# 3  3061639    -13  http://imgur.com/a/tPNT6    imgur 2016-10-22 05:10:00
# 4  3160267    -10  http://imgur.com/a/e6gme    imgur 2016-10-26 02:30:00
#
# [5 rows x 182 columns]

# %% [markdown]
# # Compare Trump and Hillary likes over different network

# %% [markdown]
# Trump likes on network

# %%
Donald_Trump_network = sum(Donald_Trump_total.likes)
sum(Donald_Trump_total.likes)
# Out:
# 37903307

# %% [markdown]
# Clinton likes on network

# %%
Clinton_Hillary_network = sum(Clinton_Hillary_total.likes)
sum(Clinton_Hillary_total.likes)
# Out:
# 13992404

# %% [markdown]
# Compare network usage

# %%
Donald_Trump_network = Donald_Trump_total.groupby('network').sum()['likes']
Clinton_Hillary_network = Clinton_Hillary_total.groupby('network').sum()['likes']

# %%
Donald_Trump_network.plot.bar()

# %%
Clinton_Hillary_network.plot.bar()

# %% [markdown]
# Find value from Facebook, Imgur, Instagram, Twitter and get who have more more social media 'likes'.

# %%
network_data = pd.concat([Donald_Trump_network, Clinton_Hillary_network], axis=1)
network_data.columns=['Trump','Hillary']

# %%
network_data.head()
# Out:
#               Trump  Hillary
# network
# facebook   13094828  7411606
# imgur        110920    47455
# instagram  22494612  5794669
# twitter     2202947   738674

# %% [markdown]
# The above indicates Trump had more social media 'likes' than Hillary. The most used network is instagram.

# %%
network_data.plot(kind='bar')

# %% [markdown]
# The number of social media 'likes' by time in 2016

# %%
Clinton_Hillary = pd.concat([Hillary, Clinton], ignore_index=True, join="inner")
Clinton_Hillary = Clinton_Hillary[Clinton_Hillary['timestamp'] > datetime(2016, 1, 1)]
Clinton_Hillary.sort_values (['timestamp'], inplace = True)
Clinton_Hillary = Clinton_Hillary.drop_duplicates(['id'])

# %%
Donald_Trump = pd.concat([Donald,Trump], ignore_index=True, join="inner")
Donald_Trump = Donald_Trump[Donald_Trump['timestamp'] > datetime(2016, 1, 1)]
Donald_Trump.sort_values(['timestamp'], inplace = True)
Donald_Trump = Donald_Trump.drop_duplicates(['id'])

# %%
Clinton_Hillary['year'] = pd.DatetimeIndex(Clinton_Hillary['timestamp']).year
Clinton_Hillary['month'] = pd.DatetimeIndex(Clinton_Hillary['timestamp']).month
Clinton_Hillary['day'] = pd.DatetimeIndex(Clinton_Hillary['timestamp']).day
Clinton_Hillary_agg = Clinton_Hillary.groupby([Clinton_Hillary['year'], Clinton_Hillary['month']])['likes'].sum()

Donald_Trump['year'] = pd.DatetimeIndex(Donald_Trump['timestamp']).year
Donald_Trump['month'] = pd.DatetimeIndex(Donald_Trump['timestamp']).month
Donald_Trump['day'] = pd.DatetimeIndex(Donald_Trump['timestamp']).day
Donald_Trump_agg = Donald_Trump.groupby([Donald_Trump['year'], Donald_Trump['month']])['likes'].sum()

data = pd.concat([Clinton_Hillary_agg, Donald_Trump_agg], axis = 1)
data.columns = ['Hillary', 'Trump']
data.plot()

# %%
hillary_day_counts = Clinton_Hillary["day"].value_counts()
hillary_day_counts.sort_index(inplace=True)

trump_day_counts = Donald_Trump["day"].value_counts()
trump_day_counts.sort_index(inplace=True)

# %%
day_counts = pd.concat( [hillary_day_counts, trump_day_counts], axis=1)
day_counts.columns = ["Hillary", "Trump"]
day_counts.plot()

# %% [markdown]
# The above indicates there is a significantly increase at end, maybe because of the Debates and the final days of campaign. People are more like discussing about Trump everyday in Nov.

# %% [markdown]
# Trump have more social media 'likes' than Hillary, also Trump have more likes than Hillary and more activity.

# %% [markdown]
# # poll - Input CSV file

# %%
county_facts = pd.read_csv('./2016-us-election/county_facts.csv')
county_facts_dictionary = pd.read_csv('./2016-us-election/county_facts_dictionary.csv')
primary_results = pd.read_csv('./2016-us-election/primary_results.csv')
url = "http://elections.huffingtonpost.com/pollster/2016-general-election-trump-vs-clinton.csv"

# %%
print (primary_results.head())
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                 AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                 AL  Barbour  1005.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes
# 0    544           0.182
# 1   2387           0.800
# 2   2694           0.329
# 3   5290           0.647
# 4    222           0.078

# %%
source = rq.get(url).text

poll_data = StringIO(source)

# %%
poll_df = pd.read_csv(poll_data)

# %%
poll_df.head()
# Out:
#         Pollster  Start Date    End Date  Entry Date/Time (ET)  \
# 0  Insights West  2016-11-04  2016-11-07  2016-11-08T12:16:30Z
# 1  Insights West  2016-11-04  2016-11-07  2016-11-08T12:16:30Z
# 2  Insights West  2016-11-04  2016-11-07  2016-11-08T12:16:30Z
# 3  Insights West  2016-11-04  2016-11-07  2016-11-08T12:16:30Z
# 4       IBD/TIPP  2016-11-04  2016-11-07  2016-11-08T12:10:06Z
#
#    Number of Observations                   Population        Mode  Trump  \
# 0                   940.0                Likely Voters    Internet   41.0
# 1                     NaN     Likely Voters - Democrat    Internet    6.0
# 2                     NaN   Likely Voters - Republican    Internet   82.0
# 3                     NaN  Likely Voters - independent    Internet   38.0
# 4                  1107.0                Likely Voters  Live Phone   43.0
#
#    Clinton  Other  Undecided  \
# 0     45.0    2.0        8.0
# 1     89.0    0.0        4.0
# 2      7.0    2.0        6.0
# 3     43.0    4.0        7.0
# 4     41.0    4.0        5.0
#
#                                         Pollster URL  \
# 0  http://elections.huffingtonpost.com/pollster/p...
# 1  http://elections.huffingtonpost.com/pollster/p...
# 2  http://elections.huffingtonpost.com/pollster/p...
# 3  http://elections.huffingtonpost.com/pollster/p...
# 4  http://elections.huffingtonpost.com/pollster/p...
#
#                                           Source URL     Partisan Affiliation  \
# 0  http://www.insightswest.com/news/clinton-is-ah...  Nonpartisan        None
# 1  http://www.insightswest.com/news/clinton-is-ah...  Nonpartisan        None
# 2  http://www.insightswest.com/news/clinton-is-ah...  Nonpartisan        None
# 3  http://www.insightswest.com/news/clinton-is-ah...  Nonpartisan        None
# 4  http://www.investors.com/politics/ibd-tipp-pre...  Nonpartisan        None
#
#                                        Question Text  Question Iteration
# 0  As you may know, there will be a presidential ...                   1
# 1  As you may know, there will be a presidential ...                   1
# 2  As you may know, there will be a presidential ...                   1
# 3  As you may know, there will be a presidential ...                   1
# 4                                                NaN                   1

# %%
sns.factorplot('Affiliation',data=poll_df,kind='count')

# %%
sns.factorplot('Affiliation',data=poll_df,hue='Population',kind='count')

# %%
sns.factorplot('Mode',data=poll_df,kind='count')

# %% [markdown]
# Did the poll results favor Clinton or Trump?

# %%
avg = pd.DataFrame(poll_df.mean())
avg.drop(['Number of Observations','Question Iteration'],axis=0,inplace=True)

std = pd.DataFrame(poll_df.std())
std.drop(['Number of Observations','Question Iteration'],axis=0,inplace=True)


poll_avg = pd.concat([avg,std],axis=1)
poll_avg.columns = ['Average','Stdev']
poll_avg
# Out:
#              Average      Stdev
# Trump      40.643890  23.566390
# Clinton    42.733903  25.298731
# Other       5.806011   5.009533
# Undecided   9.315068   6.253118

# %% [markdown]
# The race seems to be really close, with results in favour of Clinton with a higher standard deviation than for Trump.

# %%
poll_df['Difference'] = (poll_df.Clinton - poll_df.Trump)/100

poll_df.head()
# Out:
#         Pollster  Start Date    End Date  Entry Date/Time (ET)  \
# 0  Insights West  2016-11-04  2016-11-07  2016-11-08T12:16:30Z
# 1  Insights West  2016-11-04  2016-11-07  2016-11-08T12:16:30Z
# 2  Insights West  2016-11-04  2016-11-07  2016-11-08T12:16:30Z
# 3  Insights West  2016-11-04  2016-11-07  2016-11-08T12:16:30Z
# 4       IBD/TIPP  2016-11-04  2016-11-07  2016-11-08T12:10:06Z
#
#    Number of Observations                   Population        Mode  Trump  \
# 0                   940.0                Likely Voters    Internet   41.0
# 1                     NaN     Likely Voters - Democrat    Internet    6.0
# 2                     NaN   Likely Voters - Republican    Internet   82.0
# 3                     NaN  Likely Voters - independent    Internet   38.0
# 4                  1107.0                Likely Voters  Live Phone   43.0
#
#    Clinton  Other  Undecided  \
# 0     45.0    2.0        8.0
# 1     89.0    0.0        4.0
# 2      7.0    2.0        6.0
# 3     43.0    4.0        7.0
# 4     41.0    4.0        5.0
#
#                                         Pollster URL  \
# 0  http://elections.huffingtonpost.com/pollster/p...
# 1  http://elections.huffingtonpost.com/pollster/p...
# 2  http://elections.huffingtonpost.com/pollster/p...
# 3  http://elections.huffingtonpost.com/pollster/p...
# 4  http://elections.huffingtonpost.com/pollster/p...
#
#                                           Source URL     Partisan Affiliation  \
# 0  http://www.insightswest.com/news/clinton-is-ah...  Nonpartisan        None
# 1  http://www.insightswest.com/news/clinton-is-ah...  Nonpartisan        None
# 2  http://www.insightswest.com/news/clinton-is-ah...  Nonpartisan        None
# 3  http://www.insightswest.com/news/clinton-is-ah...  Nonpartisan        None
# 4  http://www.investors.com/politics/ibd-tipp-pre...  Nonpartisan        None
#
#                                        Question Text  Question Iteration  \
# 0  As you may know, there will be a presidential ...                   1
# 1  As you may know, there will be a presidential ...                   1
# 2  As you may know, there will be a presidential ...                   1
# 3  As you may know, there will be a presidential ...                   1
# 4                                                NaN                   1
#
#    Difference
# 0        0.04
# 1        0.83
# 2       -0.75
# 3        0.05
# 4       -0.02

# %%
poll_df.tail(30)
# Out:
#                Pollster  Start Date    End Date  Entry Date/Time (ET)  \
# 1492         Quinnipiac  2015-07-23  2015-07-28  2015-08-03T00:50:33Z
# 1493   McClatchy/Marist  2015-07-22  2015-07-28  2015-08-04T00:16:54Z
# 1494   McClatchy/Marist  2015-07-22  2015-07-28  2015-08-04T00:16:54Z
# 1495   McClatchy/Marist  2015-07-22  2015-07-28  2015-08-04T00:16:54Z
# 1496   McClatchy/Marist  2015-07-22  2015-07-28  2015-08-04T00:16:54Z
# 1497                CNN  2015-07-22  2015-07-25  2015-07-27T22:01:00Z
# 1498                CNN  2015-07-22  2015-07-25  2015-07-27T22:01:00Z
# 1499                CNN  2015-07-22  2015-07-25  2015-07-27T22:01:00Z
# 1500                CNN  2015-07-22  2015-07-25  2015-07-27T22:01:00Z
# 1501            PPP (D)  2015-07-20  2015-07-21  2015-07-23T17:55:26Z
# 1502            PPP (D)  2015-07-20  2015-07-21  2015-07-23T17:55:26Z
# 1503            PPP (D)  2015-07-20  2015-07-21  2015-07-23T17:55:26Z
# 1504            PPP (D)  2015-07-20  2015-07-21  2015-07-23T17:55:26Z
# 1505  Suffolk/USA Today  2015-07-09  2015-07-12  2015-07-16T00:19:28Z
# 1506  Suffolk/USA Today  2015-07-09  2015-07-12  2015-07-16T00:19:28Z
# 1507  Suffolk/USA Today  2015-07-09  2015-07-12  2015-07-16T00:19:28Z
# 1508  Suffolk/USA Today  2015-07-09  2015-07-12  2015-07-16T00:19:28Z
# 1509                CNN  2015-06-26  2015-06-28  2015-07-01T18:33:34Z
# 1510                CNN  2015-06-26  2015-06-28  2015-07-01T18:33:34Z
# 1511                CNN  2015-06-26  2015-06-28  2015-07-01T18:33:34Z
# 1512                CNN  2015-06-26  2015-06-28  2015-07-01T18:33:34Z
# 1513                FOX  2015-06-21  2015-06-23  2015-06-25T19:39:57Z
# 1514   YouGov/Economist  2015-06-20  2015-06-22  2015-06-26T01:02:40Z
# 1515   YouGov/Economist  2015-06-20  2015-06-22  2015-06-26T01:02:40Z
# 1516   YouGov/Economist  2015-06-20  2015-06-22  2015-06-26T01:02:40Z
# 1517   YouGov/Economist  2015-06-20  2015-06-22  2015-06-26T01:02:40Z
# 1518         Quinnipiac  2015-05-19  2015-05-26  2015-05-28T21:52:59Z
# 1519         Quinnipiac  2015-05-19  2015-05-26  2015-05-28T21:52:59Z
# 1520         Quinnipiac  2015-05-19  2015-05-26  2015-05-28T21:52:59Z
# 1521         Quinnipiac  2015-05-19  2015-05-26  2015-05-28T21:52:59Z
#
#       Number of Observations                       Population        Mode  \
# 1492                     NaN  Registered Voters - independent  Live Phone
# 1493                   964.0                Registered Voters  Live Phone
# 1494                     NaN     Registered Voters - Democrat  Live Phone
# 1495                     NaN   Registered Voters - Republican  Live Phone
# 1496                     NaN  Registered Voters - independent  Live Phone
# 1497                   898.0                Registered Voters  Live Phone
# 1498                     NaN     Registered Voters - Democrat  Live Phone
# 1499                     NaN   Registered Voters - Republican  Live Phone
# 1500                     NaN  Registered Voters - independent  Live Phone
# 1501                  1087.0                    Likely Voters  IVR/Online
# 1502                   496.0         Likely Voters - Democrat  IVR/Online
# 1503                   524.0       Likely Voters - Republican  IVR/Online
# 1504                     NaN      Likely Voters - independent  IVR/Online
# 1505                  1000.0                    Likely Voters  Live Phone
# 1506                   369.0         Likely Voters - Democrat  Live Phone
# 1507                   313.0       Likely Voters - Republican  Live Phone
# 1508                   315.0      Likely Voters - independent  Live Phone
# 1509                   890.0                Registered Voters  Live Phone
# 1510                     NaN     Registered Voters - Democrat  Live Phone
# 1511                     NaN   Registered Voters - Republican  Live Phone
# 1512                     NaN  Registered Voters - independent  Live Phone
# 1513                  1005.0                Registered Voters  Live Phone
# 1514                   869.0                Registered Voters    Internet
# 1515                   313.0     Registered Voters - Democrat    Internet
# 1516                   235.0   Registered Voters - Republican    Internet
# 1517                   266.0  Registered Voters - independent    Internet
# 1518                  1711.0                Registered Voters  Live Phone
# 1519                   748.0     Registered Voters - Democrat  Live Phone
# 1520                   679.0   Registered Voters - Republican  Live Phone
# 1521                     NaN  Registered Voters - independent  Live Phone
#
#       Trump  Clinton  Other  Undecided  \
# 1492   35.0     45.0    7.0       13.0
# 1493   38.0     54.0    NaN        8.0
# 1494    5.0     92.0    NaN        3.0
# 1495   74.0     20.0    NaN        6.0
# 1496   41.0     48.0    NaN       11.0
# 1497   40.0     56.0    4.0        0.0
# 1498   10.0     89.0    2.0        NaN
# 1499   72.0     24.0    3.0        NaN
# 1500   40.0     54.0    6.0        NaN
# 1501   37.0     50.0    NaN       13.0
# 1502    8.0     86.0    NaN        6.0
# 1503   73.0     12.0    NaN       15.0
# 1504   37.0     41.0    NaN       21.0
# 1505   34.0     51.0    NaN       16.0
# 1506    5.0     88.0    NaN        7.0
# 1507   68.0     15.0    NaN       18.0
# 1508   34.0     44.0    NaN       23.0
# 1509   35.0     59.0    6.0        0.0
# 1510    8.0     91.0    1.0        NaN
# 1511   71.0     19.0   10.0        NaN
# 1512   33.0     59.0    7.0        NaN
# 1513   34.0     51.0    3.0       12.0
# 1514   35.0     46.0    NaN       18.0
# 1515    6.0     86.0    NaN        8.0
# 1516   65.0     12.0    NaN       24.0
# 1517   34.0     45.0    NaN       21.0
# 1518   32.0     50.0    3.0       14.0
# 1519    5.0     89.0    0.0        5.0
# 1520   68.0      9.0    4.0       19.0
# 1521   32.0     47.0    3.0       18.0
#
#                                            Pollster URL  \
# 1492  http://elections.huffingtonpost.com/pollster/p...
# 1493  http://elections.huffingtonpost.com/pollster/p...
# 1494  http://elections.huffingtonpost.com/pollster/p...
# 1495  http://elections.huffingtonpost.com/pollster/p...
# 1496  http://elections.huffingtonpost.com/pollster/p...
# 1497  http://elections.huffingtonpost.com/pollster/p...
# 1498  http://elections.huffingtonpost.com/pollster/p...
# 1499  http://elections.huffingtonpost.com/pollster/p...
# 1500  http://elections.huffingtonpost.com/pollster/p...
# 1501  http://elections.huffingtonpost.com/pollster/p...
# 1502  http://elections.huffingtonpost.com/pollster/p...
# 1503  http://elections.huffingtonpost.com/pollster/p...
# 1504  http://elections.huffingtonpost.com/pollster/p...
# 1505  http://elections.huffingtonpost.com/pollster/p...
# 1506  http://elections.huffingtonpost.com/pollster/p...
# 1507  http://elections.huffingtonpost.com/pollster/p...
# 1508  http://elections.huffingtonpost.com/pollster/p...
# 1509  http://elections.huffingtonpost.com/pollster/p...
# 1510  http://elections.huffingtonpost.com/pollster/p...
# 1511  http://elections.huffingtonpost.com/pollster/p...
# 1512  http://elections.huffingtonpost.com/pollster/p...
# 1513  http://elections.huffingtonpost.com/pollster/p...
# 1514  http://elections.huffingtonpost.com/pollster/p...
# 1515  http://elections.huffingtonpost.com/pollster/p...
# 1516  http://elections.huffingtonpost.com/pollster/p...
# 1517  http://elections.huffingtonpost.com/pollster/p...
# 1518  http://elections.huffingtonpost.com/pollster/p...
# 1519  http://elections.huffingtonpost.com/pollster/p...
# 1520  http://elections.huffingtonpost.com/pollster/p...
# 1521  http://elections.huffingtonpost.com/pollster/p...
#
#                                              Source URL     Partisan  \
# 1492  http://www.quinnipiac.edu/news-and-events/quin...  Nonpartisan
# 1493  http://maristpoll.marist.edu/wp-content/misc/u...  Nonpartisan
# 1494  http://maristpoll.marist.edu/wp-content/misc/u...  Nonpartisan
# 1495  http://maristpoll.marist.edu/wp-content/misc/u...  Nonpartisan
# 1496  http://maristpoll.marist.edu/wp-content/misc/u...  Nonpartisan
# 1497  http://www.cnn.com/2015/07/26/politics/cnn-orc...  Nonpartisan
# 1498  http://www.cnn.com/2015/07/26/politics/cnn-orc...  Nonpartisan
# 1499  http://www.cnn.com/2015/07/26/politics/cnn-orc...  Nonpartisan
# 1500  http://www.cnn.com/2015/07/26/politics/cnn-orc...  Nonpartisan
# 1501  http://www.publicpolicypolling.com/pdf/2015/PP...     Pollster
# 1502  http://www.publicpolicypolling.com/pdf/2015/PP...     Pollster
# 1503  http://www.publicpolicypolling.com/pdf/2015/PP...     Pollster
# 1504  http://www.publicpolicypolling.com/pdf/2015/PP...     Pollster
# 1505  http://www.suffolk.edu/documents/SUPRC/7_15_20...  Nonpartisan
# 1506  http://www.suffolk.edu/documents/SUPRC/7_15_20...  Nonpartisan
# 1507  http://www.suffolk.edu/documents/SUPRC/7_15_20...  Nonpartisan
# 1508  http://www.suffolk.edu/documents/SUPRC/7_15_20...  Nonpartisan
# 1509  http://i2.cdn.turner.com/cnn/2015/images/06/30...  Nonpartisan
# 1510  http://i2.cdn.turner.com/cnn/2015/images/06/30...  Nonpartisan
# 1511  http://i2.cdn.turner.com/cnn/2015/images/06/30...  Nonpartisan
# 1512  http://i2.cdn.turner.com/cnn/2015/images/06/30...  Nonpartisan
# 1513  http://www.foxnews.com/politics/interactive/20...  Nonpartisan
# 1514  https://d25d2506sfb94s.cloudfront.net/cumulus_...  Nonpartisan
# 1515  https://d25d2506sfb94s.cloudfront.net/cumulus_...  Nonpartisan
# 1516  https://d25d2506sfb94s.cloudfront.net/cumulus_...  Nonpartisan
# 1517  https://d25d2506sfb94s.cloudfront.net/cumulus_...  Nonpartisan
# 1518  http://www.quinnipiac.edu/images/polling/us/us...  Nonpartisan
# 1519  http://www.quinnipiac.edu/images/polling/us/us...  Nonpartisan
# 1520  http://www.quinnipiac.edu/images/polling/us/us...  Nonpartisan
# 1521  http://www.quinnipiac.edu/images/polling/us/us...  Nonpartisan
#
#      Affiliation Question Text  Question Iteration  Difference
# 1492        None           NaN                   1        0.10
# 1493        None           NaN                   1        0.16
# 1494        None           NaN                   1        0.87
# 1495        None           NaN                   1       -0.54
# 1496        None           NaN                   1        0.07
# 1497        None           NaN                   1        0.16
# 1498        None           NaN                   1        0.79
# 1499        None           NaN                   1       -0.48
# 1500        None           NaN                   1        0.14
# 1501         Dem           NaN                   1        0.13
# 1502         Dem           NaN                   1        0.78
# 1503         Dem           NaN                   1       -0.61
# 1504         Dem           NaN                   1        0.04
# 1505        None           NaN                   1        0.17
# 1506        None           NaN                   1        0.83
# 1507        None           NaN                   1       -0.53
# 1508        None           NaN                   1        0.10
# 1509        None           NaN                   1        0.24
# 1510        None           NaN                   1        0.83
# 1511        None           NaN                   1       -0.52
# 1512        None           NaN                   1        0.26
# 1513        None           NaN                   1        0.17
# 1514        None           NaN                   1        0.11
# 1515        None           NaN                   1        0.80
# 1516        None           NaN                   1       -0.53
# 1517        None           NaN                   1        0.11
# 1518        None           NaN                   1        0.18
# 1519        None           NaN                   1        0.84
# 1520        None           NaN                   1       -0.59
# 1521        None           NaN                   1        0.15

# %%
poll_df.corr()['Trump'].sort_values(ascending=False)[1:]
# Out:
# Undecided                 0.030041
# Number of Observations    0.003430
# Question Iteration       -0.051198
# Other                    -0.080906
# Clinton                  -0.918489
# Difference               -0.977909
# const                          NaN
# Name: Trump, dtype: float64

# %%
poll_df.corr()['Clinton'].sort_values(ascending=False)[1:]
# Out:
# Difference                0.980859
# Number of Observations    0.036823
# Question Iteration       -0.072198
# Other                    -0.200328
# Undecided                -0.271885
# Trump                    -0.918489
# const                          NaN
# Name: Clinton, dtype: float64

# %%
poll_df.corr()['Other'].sort_values(ascending=False)[1:]
# Out:
# Undecided                 0.426359
# Number of Observations   -0.046247
# Difference               -0.065959
# Trump                    -0.080906
# Question Iteration       -0.092517
# Clinton                  -0.200328
# const                          NaN
# Name: Other, dtype: float64

# %%
poll_df.corr()['Undecided'].sort_values(ascending=False)[1:]
# Out:
# Other                     0.426359
# Trump                     0.030041
# Question Iteration       -0.062080
# Number of Observations   -0.104781
# Difference               -0.158444
# Clinton                  -0.271885
# const                          NaN
# Name: Undecided, dtype: float64

# %% [markdown]
# # Scatterplots

# %%
_ = poll_df.plot.scatter('Trump', 'Difference')
_ = poll_df.plot.scatter('Clinton', 'Difference')
_ = poll_df.plot.scatter('Other', 'Difference')
_ = poll_df.plot.scatter('Undecided', 'Difference')

# %% [markdown]
# # linear regression

# %%
beta, alpha = np.polyfit(poll_df.Trump, poll_df.Difference, 1)
print('beta: %0.3f, alpha: %0.1f.' % (beta, alpha))
print()
# Out:
# beta: -0.020, alpha: 0.8.

# %%
beta, alpha = np.polyfit(poll_df.Clinton, poll_df.Difference, 1)
print('beta: %0.3f, alpha: %0.1f.' % (beta, alpha))
print()
# Out:
# beta: 0.019, alpha: -0.8.

# %%
beta, alpha = np.polyfit(poll_df.Other, poll_df.Difference, 1)
print('beta: %0.3f, alpha: %0.1f.' % (beta, alpha))
print()
# Out:
# beta: nan, alpha: nan.

# %%
beta, alpha = np.polyfit(poll_df.Undecided, poll_df.Difference, 1)
print('beta: %0.3f, alpha: %0.1f.' % (beta, alpha))
print()
# Out:
# beta: nan, alpha: nan.

# %% [markdown]
# # Using difference to get poll result

# %%
poll_df.plot('Start Date','Difference',figsize=(15,4),marker='o',linestyle='-')

# %% [markdown]
# The difference is Clinton - Trump. So a positive difference indicates a Clinton lead, and a negative difference indicates a Trump lead.
# The visualisation indicates that Clinton has a slight lead in the polls, on average.

# %% [markdown]
# # In Network, Trump had a distinct advantage,people more like to discuss Trump on internet, so trump enjoy high popularity, but Clinton had a distinct advantage in Poll all time.
